# %% [markdown]
# # 03_03: Indexing and slicing

# %%
import math
import collections
import dataclasses
import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %%
monalisa = np.load('monalisa.npy')

# %%
monalisa.shape
# Out:
# (1198, 804, 3)

# %%
pp.imshow(monalisa)

# %%
monalisa[600, 400, 0]
# Out:
# np.uint8(247)

# %%
int(monalisa[600, 400, 0]), float(monalisa[600, 400, 0])
# Out:
# (247, 247.0)

# %%
monalisa[-50, -50, 1]
# Out:
# np.uint8(11)

# %%
monalisa[1198 - 50, 804 - 50, 1], monalisa[1148, 754, 1]
# Out:
# (np.uint8(11), np.uint8(11))

# %%
monalisa[1000, 900, 2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 monalisa[1000, 900, 2]
#
# IndexError: index 900 is out of bounds for axis 1 with size 804

# %%
monalisa[1200, 754, 0] = monalisa[1200, 754, 1] = monalisa[1200, 754, 2] = 0
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 monalisa[1200, 754, 0] = monalisa[1200, 754, 1] = monalisa[1200, 754, 2] = 0
#
# IndexError: index 1200 is out of bounds for axis 0 with size 1198

# %%
just_a_list = [[1,2,3],[4,5,6],[7,8,9]]

# %%
just_a_list[1,2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 just_a_list[1,2]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
just_a_list[1]
# Out:
# [4, 5, 6]

# %%
just_a_list[1][2]
# Out:
# 6

# %%
pp.imshow(monalisa[300:800, 400:600, 0:3])

# %%
pp.imshow(monalisa[800:, :, :])

# %%
pp.imshow(monalisa[100:400, ...])

# %%
pp.imshow(monalisa[::20, ::20, :])

# %%
pp.imshow(monalisa[::-1, :, :])

# %%
row = monalisa[20, ::20, 0]

# %%
row.shape
# Out:
# (41,)

# %%
row
# Out:
# array([104,  81, 107, 100,  90,  98,  94, 103, 103,  97,  99, 105, 116,
#        100,  90,  97,  85,  97,  93,  97, 104,  94,  85, 112,  92,  98,
#         88,  81, 106,  79,  80,  91,  82, 100, 104,  88,  88,  79,  81,
#         81,  88], dtype=uint8)

# %%
pp.plot(row)

# %%
rect = monalisa[20:21, ::20, 0]

# %%
rect
# Out:
# array([[104,  81, 107, 100,  90,  98,  94, 103, 103,  97,  99, 105, 116,
#         100,  90,  97,  85,  97,  93,  97, 104,  94,  85, 112,  92,  98,
#          88,  81, 106,  79,  80,  91,  82, 100, 104,  88,  88,  79,  81,
#          81,  88]], dtype=uint8)

# %%
rect.shape
# Out:
# (1, 41)

# %%
monalisa[20:300, 20:300, :] = 200

# %%
pp.imshow(monalisa)

# %%
monalisa[20:300, 20:300, :] = np.random.randint(100, 255, size=(280, 280, 3))

# %%
pp.imshow(monalisa)

# %%
monalisa_bw = np.loadtxt('monalisa.txt')

# %%
pp.imshow(monalisa_bw, cmap='gray')

# %%
monalisa_bw < 120

# %%
monalisa_bw[monalisa_bw < 120] = 0

# %%
pp.imshow(monalisa_bw, cmap='gray')

# %%
mylist = [0,1,2,3,4,5]

# %%
myslice = mylist[0:4]

# %%
myslice[2] = myslice[3] = 100

# %%
myslice

# %%
mylist

# %%
monaslice = monalisa[:, 300:500, :]

# %%
pp.imshow(monaslice)

# %%
monaslice[:,:,:] //= 3 # integer-divide by three in place

# %%
pp.imshow(monalisa)

# %%
monacopy = monalisa_bw.copy()
