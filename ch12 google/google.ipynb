# %%
from youtube_comment_downloader import YoutubeCommentDownloader
from textblob import TextBlob

# YouTube video link
url = "https://www.youtube.com/shorts/DFA-2jy9v3M"

# Get comments
downloader = YoutubeCommentDownloader()
comments = downloader.get_comments_from_url(url)

# Analyze sentiment
def get_sentiment(text):
    analysis = TextBlob(text)
    polarity = analysis.sentiment.polarity
    
    if polarity > 0:
        return "Positive"
    elif polarity < 0:
        return "Negative"
    else:
        return "Neutral"

# Process comments
count = 0
for comment in comments:
    text = comment['text']
    sentiment = get_sentiment(text)
    
    print(f"Comment: {text}")
    print(f"Sentiment: {sentiment}")
    print("-" * 50)
    
    count += 1
    if count >= 20:  # limit for demo
        break
# Out:
# Comment: Fabio looks like a homosexual MJ… stop giving him satisfaction😂
# Sentiment: Neutral
# --------------------------------------------------
# Comment: Fabio made this video 🤣🤣🤣🤣
# Sentiment: Neutral
# --------------------------------------------------
# Comment: Does it really matter? Why would we be looking at his socks
# Sentiment: Positive
# --------------------------------------------------
# Comment: M.J was long term perfected , Jaafar was not as conditioned hence ankles swelling but was the highest form of appreciation his flawless imitation
# Sentiment: Positive
# --------------------------------------------------
# Comment: Michael 2 coming soon
# Sentiment: Neutral
# --------------------------------------------------
# Comment: Let him get the role in pt 2 Michael Jackson movie
# Sentiment: Neutral
# --------------------------------------------------
# Comment: Fabio Jackson may be in the second movie
# Sentiment: Neutral
# --------------------------------------------------
# Comment: fabio my ahhhh who is he anyways? hes not even a jackson
# Sentiment: Neutral
# --------------------------------------------------
# Comment: Cuz Michael was his ankle
# Sentiment: Neutral
# --------------------------------------------------
# Comment: Fabio does not look more like Michael. Jaffar looks like his uncle. Especially when he was younger
# Sentiment: Positive
# --------------------------------------------------
# Comment: No one wanted Fabio to play Michael. The guy cant sing or dance.
# Only a TRUE Jackson should play a Jackson !
# Sentiment: Positive
# --------------------------------------------------
# Comment: Fresh off this movie from like 5 hours ago and I feel he played this role perfectly
# Sentiment: Positive
# --------------------------------------------------
# Comment: Fabio is butt hurt and is not related,  and def dont know MJ personal side, where his nephew obviously does,  plus jafaar looks like mj before surgery,  Fabio has mental illness
# Sentiment: Negative
# --------------------------------------------------
# Comment: Loved the movie!!!
# And it felt like I was watching MJ live on the screen… great performance!!
# Loved it 🎉🎉🎉❤❤❤
# Sentiment: Positive
# --------------------------------------------------
# Comment: It's not a documentary it's a biopic.
# Sentiment: Neutral
# --------------------------------------------------
# Comment: Not sure why didn’t you use Prince?
# He has Michael’s DNA and looks
# Sentiment: Negative
# --------------------------------------------------
# Comment: Okay, but his not the Ring
# Sentiment: Positive
# --------------------------------------------------
# Comment: I was wondering about the socks.
# Sentiment: Neutral
# --------------------------------------------------
# Comment: 340th comment
# Sentiment: Neutral
# --------------------------------------------------
# Comment: 🔥Nephew Jaafar🥰 I am 61 and you took me back to Off the wall Album
# My  eyes flowed with tears 🥲 the hospital screen Uncle was In you.
# Rose 🌹 PEDALS @ ur 👣
# Huge Hug from DETROIT ❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️
# Sentiment: Positive
# --------------------------------------------------
